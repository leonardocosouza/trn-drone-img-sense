# %%
#https://docs.ultralytics.com/

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

# %%
results = model ('https://ultralytics.com/images/bus.jpg', save=True)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /yolov7/notebook/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 92.4ms
# Speed: 1.5ms preprocess, 92.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = '/yolov7/notebook/runs/detect/predict/bus.jpg'

image= mpimg.imread(img)
plt.imshow(image)
plt.axis('off')
plt.show()
